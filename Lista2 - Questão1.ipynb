# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt
import dataframe_image as dfi

# %% [markdown]
# ## Análise e Limpeza da Base de Dados

# %%
train = pd.read_csv('../datasets/adult.data', sep=",", na_values=['?'])  
test  = pd.read_csv('../datasets/adult.test', sep=",", na_values=['?'])

# %%
train = pd.read_csv('../datasets/adult.data', sep=",", na_values=['?'])  
test  = pd.read_csv('../datasets/adult.test', sep=",", na_values=['?'])    

# Removendo espaços vazios
train_trin = train.replace(r'\s*(.*?)\s*', r'\1', regex=True)
test_trin = test.replace(r'\s*(.*?)\s*', r'\1', regex=True)

train_trin.to_csv("adult.data",sep=",")
test_trin.to_csv("adult.test",sep=",")

# %%
labels = ["index","age", "workclass", "fnlwgt", "education", "educationnum", "maritalstatus", "occupation", "relationship", "race", "sex", "capitalgain", "capitalloss", "hoursperweek", "nativecountry", "target"]

train = pd.read_csv('adult.data', sep=",", na_values=['?'])  
test  = pd.read_csv('adult.test', sep=",", na_values=['?'])    

test_clean = test.dropna()
train_clean = train.dropna()

# %%
train_clean
# Out:
#        Unnamed: 0  age  workclass  fnlwgt  education  education-num  \
# 0               0   39          5   77516          9             13
# 1               1   50          4   83311          9             13
# 2               2   38          2  215646         11              9
# 3               3   53          2  234721          1              7
# 4               4   28          2  338409          9             13
# ...           ...  ...        ...     ...        ...            ...
# 32556       32556   27          2  257302          7             12
# 32557       32557   40          2  154374         11              9
# 32558       32558   58          2  151910         11              9
# 32559       32559   22          2  201490         11              9
# 32560       32560   52          3  287927         11              9
#
#            marital-status         occupation   relationship   race     sex  \
# ...

# %%
lbl_workclass_test = LabelEncoder()
lbl_workclass_train = LabelEncoder()

test_clean['workclass']=lbl_workclass_test.fit_transform(test_clean['workclass'])
train_clean['workclass']=lbl_workclass_train.fit_transform(train_clean['workclass'])


lbl_education_test = LabelEncoder()
lbl_education_train = LabelEncoder()

test_clean['education']=lbl_education_test.fit_transform(test_clean['education'])
train_clean['education']=lbl_education_train.fit_transform(train_clean['education'])


lbl_maritalstatus_test = LabelEncoder()
lbl_maritalstatus_train = LabelEncoder()

test_clean['maritalstatus']=lbl_maritalstatus_test.fit_transform(test_clean['maritalstatus'])
train_clean['maritalstatus']=lbl_maritalstatus_train.fit_transform(train_clean['maritalstatus'])


lbl_occupation_test = LabelEncoder()
lbl_occupation_train = LabelEncoder()

test_clean['occupation']=lbl_occupation_test.fit_transform(test_clean['occupation'])
train_clean['occupation']=lbl_occupation_train.fit_transform(train_clean['occupation'])


lbl_relationship_test = LabelEncoder()
lbl_relationship_train = LabelEncoder()

test_clean['relationship']=lbl_relationship_test.fit_transform(test_clean['relationship'])
train_clean['relationship']=lbl_relationship_train.fit_transform(train_clean['relationship'])


lbl_race_test = LabelEncoder()
lbl_race_train = LabelEncoder()

test_clean['race']=lbl_race_test.fit_transform(test_clean['race'])
train_clean['race']=lbl_race_train.fit_transform(train_clean['race'])

lbl_sex_test = LabelEncoder()
lbl_sex_train = LabelEncoder()

test_clean['sex']=lbl_sex_test.fit_transform(test_clean['sex'])
train_clean['sex']=lbl_sex_train.fit_transform(train_clean['sex'])

lbl_nativecountry_test = LabelEncoder()
lbl_nativecountry_train = LabelEncoder()

test_clean['nativecountry']=lbl_nativecountry_test.fit_transform(test_clean['nativecountry'])
train_clean['nativecountry']=lbl_nativecountry_train.fit_transform(train_clean['nativecountry'])

lbl_target_test = LabelEncoder()
lbl_target_train = LabelEncoder()

test_clean['target']=lbl_target_test.fit_transform(test_clean['target'])
train_clean['target']=lbl_target_train.fit_transform(train_clean['target'])

frames = [test_clean, train_clean ]

result = pd.concat(frames)
r2 = result.drop('index', axis=1)
r2.to_csv("adult-full.csv",sep=",",index=False)
# Out:
# C:\Users\55989\AppData\Local\Temp/ipykernel_7284/1648107999.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_clean['workclass']=lbl_workclass_test.fit_transform(test_clean['workclass'])
# C:\Users\55989\AppData\Local\Temp/ipykernel_7284/1648107999.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_clean['workclass']=lbl_workclass_train.fit_transform(train_clean['workclass'])
# C:\Users\55989\AppData\Local\Temp/ipykernel_7284/1648107999.py:11: SettingWithCopyWarning:
# ...

# %%
# test_clean
# frames = [train, test]

# result = pd.concat(frames)
# result
# save = result.describe()
dataset = pd.read_csv('adult-full.csv', sep=",")  
dataset

statistics = dataset.iloc[0:: , 10::].describe()
dfi.export(statistics, "fig3-2.png")

# %%
train_clean
# Out:
#        index  age  workclass  fnlwgt  education  educationnum  maritalstatus  \
# 0          0   39          5   77516          9            13              4
# 1          1   50          4   83311          9            13              2
# 2          2   38          2  215646         11             9              0
# 3          3   53          2  234721          1             7              2
# 4          4   28          2  338409          9            13              2
# ...      ...  ...        ...     ...        ...           ...            ...
# 32556  32556   27          2  257302          7            12              2
# 32557  32557   40          2  154374         11             9              2
# 32558  32558   58          2  151910         11             9              6
# 32559  32559   22          2  201490         11             9              4
# 32560  32560   52          3  287927         11             9              2
#
# ...

# %%
train_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30162 entries, 0 to 32560
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      30162 non-null  int64
#  1   age             30162 non-null  int64
#  2   workclass       30162 non-null  object
#  3   fnlwgt          30162 non-null  int64
#  4   education       30162 non-null  object
#  5   education-num   30162 non-null  int64
#  6   marital-status  30162 non-null  object
#  7   occupation      30162 non-null  object
#  8   relationship    30162 non-null  object
#  9   race            30162 non-null  object
#  10  sex             30162 non-null  object
#  11  capital-gain    30162 non-null  int64
#  12  capital-loss    30162 non-null  int64
#  13  hours-per-week  30162 non-null  int64
#  14  native-country  30162 non-null  object
#  15  target          30162 non-null  object
# dtypes: int64(7), object(9)
# memory usage: 3.9+ MB

# %%
test_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15060 entries, 0 to 16280
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      15060 non-null  int64
#  1   age             15060 non-null  int64
#  2   workclass       15060 non-null  object
#  3   fnlwgt          15060 non-null  int64
#  4   education       15060 non-null  object
#  5   education-num   15060 non-null  int64
#  6   marital-status  15060 non-null  object
#  7   occupation      15060 non-null  object
#  8   relationship    15060 non-null  object
#  9   race            15060 non-null  object
#  10  sex             15060 non-null  object
#  11  capital-gain    15060 non-null  int64
#  12  capital-loss    15060 non-null  int64
#  13  hours-per-week  15060 non-null  int64
#  14  native-country  15060 non-null  object
#  15  target          15060 non-null  object
# dtypes: int64(7), object(9)
# memory usage: 2.0+ MB

# %%
test_clean["workclass"].value_counts()
# Out:
# Private             11021
# Self-emp-not-inc     1297
# Local-gov            1033
# State-gov             667
# Self-emp-inc          572
# Federal-gov           463
# Without-pay             7
# Name: workclass, dtype: int64

# %%
test_clean["occupation"].value_counts()
# Out:
# Exec-managerial      1992
# Craft-repair         1990
# Prof-specialty       1970
# Sales                1824
# Adm-clerical         1819
# Other-service        1596
# Machine-op-inspct    1004
# Transport-moving      744
# Handlers-cleaners     696
# Tech-support          508
# Farming-fishing       491
# Protective-serv       332
# Priv-house-serv        89
# Armed-Forces            5
# Name: occupation, dtype: int64

# %%
test_clean["native-country"].value_counts()
# Out:
# United-States                 13788
# Mexico                          293
# Philippines                      95
# Puerto-Rico                      66
# Germany                          65
# Canada                           56
# El-Salvador                      47
# India                            47
# China                            45
# Cuba                             41
# England                          33
# Italy                            32
# South                            30
# Dominican-Republic               30
# Japan                            30
# Portugal                         28
# Haiti                            27
# Columbia                         26
# Poland                           25
# Guatemala                        23
# Jamaica                          23
# Greece                           20
# Vietnam                          19
# Ecuador                          16
# Nicaragua                        15
# Peru                             15
# ...

# %% [markdown]
# ## Acuracia vs Número de Vizinhos

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# %%
train_x = train_clean.iloc[0:: , 1:15].copy()
train_y = train_clean.iloc[0:: , 15:16].copy()

test_x = test_clean.iloc[0:: , 1:15].copy()
test_y = test_clean.iloc[0:: , 15:16].copy()

# %%
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(train_x,train_y)
# Out:
# C:\Users\55989\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# KNeighborsClassifier(n_neighbors=3)

# %%
YtestPred = knn.predict(test_x)
# Out:
# C:\Users\55989\anaconda3\lib\site-packages\sklearn\base.py:441: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(

# %%
accuracy_score(YtestPred,test_y)
# Out:
# 0.751792828685259

# %% [markdown]
# ## Vizinhos x Acurácia

# %%
n = []
accur = []

for i in range(2,212):
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(train_x.values,train_y.values.ravel())
    YtestPred = knn.predict(test_x)
    
    n.append(i)
    accur.append(accuracy_score(YtestPred,test_y.values.ravel()))
# Out:
# C:\Users\55989\anaconda3\lib\site-packages\sklearn\base.py:434: UserWarning: X has feature names, but KNeighborsClassifier was fitted without feature names
#   warnings.warn(
# C:\Users\55989\anaconda3\lib\site-packages\sklearn\base.py:434: UserWarning: X has feature names, but KNeighborsClassifier was fitted without feature names
#   warnings.warn(
# C:\Users\55989\anaconda3\lib\site-packages\sklearn\base.py:434: UserWarning: X has feature names, but KNeighborsClassifier was fitted without feature names
#   warnings.warn(
# C:\Users\55989\anaconda3\lib\site-packages\sklearn\base.py:434: UserWarning: X has feature names, but KNeighborsClassifier was fitted without feature names
#   warnings.warn(
# C:\Users\55989\anaconda3\lib\site-packages\sklearn\base.py:434: UserWarning: X has feature names, but KNeighborsClassifier was fitted without feature names
#   warnings.warn(
# ...

# %%
fig = plt.plot(n, accur, color='red', label="test", )

plt.xlabel('Nº Vizinhos')
plt.ylabel('Acurácia')
plt.title("Acurácia x Nº de Vizinhos")
plt.show()

fig.savefig('acurXneighbor.png')

fig = plt.figure()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7284/4083926986.py in <module>
#       6 plt.show()
#       7
# ----> 8 fig.savefig('acurXneighbor.png')
#       9
#      10 fig = plt.figure()
#
# AttributeError: 'list' object has no attribute 'savefig'

# %%
fig, ax = plt.subplots( nrows=1, ncols=1 )  # create figure & 1 axis
ax.plot(n, accur, color='red', label="test")
ax.title.set_text('Acurácia x Nº de Vizinhos')
ax.set_xlabel('Nº de Vizinhos')
ax.set_ylabel('Acurácia')
fig.savefig('figure2.png')   # save the figure to file
fig.show()
# Out:
# C:\Users\55989\AppData\Local\Temp/ipykernel_7284/1207521747.py:7: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# ## Distância

# %%
n = []
accur = []

for i in range(2,212):
    knn = KNeighborsClassifier(n_neighbors=i, weights="distance")
    knn.fit(train_x,train_y)
    YtestPred = knn.predict(test_x)
    
    n.append(i)
    accur.append(accuracy_score(YtestPred,test_y))
# Out:
# C:\Users\55989\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\55989\anaconda3\lib\site-packages\sklearn\base.py:441: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\55989\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\55989\anaconda3\lib\site-packages\sklearn\base.py:441: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# ...

# %%
fig, ax = plt.subplots( nrows=1, ncols=1 )  # create figure & 1 axis
ax.plot(n, accur, color='red', label="test")
ax.title.set_text('Acurácia x Nº de Vizinhos (weights)')
ax.set_xlabel('Nº de Vizinhos')
ax.set_ylabel('Acurácia')
fig.savefig('figure3.png')   # save the figure to file
fig.show()
# Out:
# C:\Users\55989\AppData\Local\Temp/ipykernel_7284/309681677.py:7: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# ## Acurácia vs Número de Instâncias

# %% [markdown]
# ### A partir da base de dados sera gerado fatias que correspondem a 20%, 40%, 60%, 80% E 100% do tamanho original, o número de vizinhos sera fixado em 15 com pesos baseados na distancia

# %%
adult_full = pd.read_csv('adult-full-clean.csv', sep=",")  
adult_full_20 = adult_full.sample(frac=0.2, random_state=100)
adult_full_40 = adult_full.sample(frac=0.4, random_state=100)
adult_full_60 = adult_full.sample(frac=0.6, random_state=100)
adult_full_80 = adult_full.sample(frac=0.8, random_state=100)

adult_all = [adult_full_20, adult_full_40, adult_full_60, adult_full_80, adult_full]
for i in adult_all:
    print(i["age"].size)
# Out:
# 9044
# 18089
# 27133
# 36178
# 45222

# %% [markdown]
# ### Cada sub conjunto da base (20, 40, 60, 80 e 100%) será dividido entre 70% para treinamento e 30% para testes

# %%
tamanhos = [20, 40, 60, 80, 100]
trains = []
tests = []

for i in adult_all:

    train = i.sample(frac=0.7, random_state=100) #random state is a seed value
    test  = i.drop(train.index)

    trains.append(train)
    tests.append(test)


for i in range(0, len(trains)):
    print("Subconjuno {} %, divisão 70-30: {}-{}  ".format(tamanhos[i], trains[i]["age"].size,tests[i]["age"].size ))
# Out:
# Subconjuno 20 %, divisão 70-30: 6331-2713
# Subconjuno 40 %, divisão 70-30: 12662-5427
# Subconjuno 60 %, divisão 70-30: 18993-8140
# Subconjuno 80 %, divisão 70-30: 25325-10853
# Subconjuno 100 %, divisão 70-30: 31655-13567

# %%
train_x = trains[0].iloc[0:: , 0:15].copy()
train_y = trains[0].iloc[0:: , 14:15].copy()


test_x = tests[0].iloc[0:: , 0:15].copy()
test_y = tests[0].iloc[0:: , 14:15].copy()

# %% [markdown]
# ### Fixaremos o número de vizinhos em 30, considerando distancias uniformes

# %%
accur = []
accur_weights = []

for i in range(0, len(trains)):
    
    train_x = trains[i].iloc[0:: , 0:15].copy()
    train_y = trains[i].iloc[0:: , 14:15].copy()


    test_x = tests[i].iloc[0:: , 0:15].copy()
    test_y = tests[i].iloc[0:: , 14:15].copy()

        
    
    knn = KNeighborsClassifier(n_neighbors=30)
    knn.fit(train_x.values,train_y.values.ravel())
    YtestPred = knn.predict(test_x)
    
    accur.append(accuracy_score(YtestPred,test_y.values.ravel()))
# Out:
# C:\Users\55989\anaconda3\lib\site-packages\sklearn\base.py:434: UserWarning: X has feature names, but KNeighborsClassifier was fitted without feature names
#   warnings.warn(
# C:\Users\55989\anaconda3\lib\site-packages\sklearn\base.py:434: UserWarning: X has feature names, but KNeighborsClassifier was fitted without feature names
#   warnings.warn(
# C:\Users\55989\anaconda3\lib\site-packages\sklearn\base.py:434: UserWarning: X has feature names, but KNeighborsClassifier was fitted without feature names
#   warnings.warn(
# C:\Users\55989\anaconda3\lib\site-packages\sklearn\base.py:434: UserWarning: X has feature names, but KNeighborsClassifier was fitted without feature names
#   warnings.warn(
# C:\Users\55989\anaconda3\lib\site-packages\sklearn\base.py:434: UserWarning: X has feature names, but KNeighborsClassifier was fitted without feature names
#   warnings.warn(

# %%
fig, ax = plt.subplots( nrows=1, ncols=1 )  # create figure & 1 axis
ax.plot(tamanhos, accur, color='red', label="test", marker='o')
ax.title.set_text('Acurácia x Nº de Instâncias (k=30)')
ax.set_xlabel('Nº de Instâncias (percentual)')
ax.set_ylabel('Acurácia')
fig.savefig('figure4.png')   # save the figure to file
fig.show()
# Out:
# C:\Users\55989\AppData\Local\Temp/ipykernel_7284/430926571.py:7: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# ### Fixaremos o número de vizinhos em 30, considerando pesos de acordo com a distância

# %%
accur_weights = []

for i in range(0, len(trains)):
    
    train_x = trains[i].iloc[0:: , 0:15].copy()
    train_y = trains[i].iloc[0:: , 14:15].copy()


    test_x = tests[i].iloc[0:: , 0:15].copy()
    test_y = tests[i].iloc[0:: , 14:15].copy()

        
    
    knn = KNeighborsClassifier(n_neighbors=30, weights="distance")
    knn.fit(train_x.values,train_y.values.ravel())
    YtestPred = knn.predict(test_x)
    
    accur_weights.append(accuracy_score(YtestPred,test_y.values.ravel()))
# Out:
# C:\Users\55989\anaconda3\lib\site-packages\sklearn\base.py:434: UserWarning: X has feature names, but KNeighborsClassifier was fitted without feature names
#   warnings.warn(
# C:\Users\55989\anaconda3\lib\site-packages\sklearn\base.py:434: UserWarning: X has feature names, but KNeighborsClassifier was fitted without feature names
#   warnings.warn(
# C:\Users\55989\anaconda3\lib\site-packages\sklearn\base.py:434: UserWarning: X has feature names, but KNeighborsClassifier was fitted without feature names
#   warnings.warn(
# C:\Users\55989\anaconda3\lib\site-packages\sklearn\base.py:434: UserWarning: X has feature names, but KNeighborsClassifier was fitted without feature names
#   warnings.warn(
# C:\Users\55989\anaconda3\lib\site-packages\sklearn\base.py:434: UserWarning: X has feature names, but KNeighborsClassifier was fitted without feature names
#   warnings.warn(

# %%
fig, ax = plt.subplots( nrows=1, ncols=1 )  # create figure & 1 axis
ax.plot(tamanhos, accur, color='red', label="test", marker='o')
ax.title.set_text('Acurácia x Nº de Instâncias (weights, k=30)')
ax.set_xlabel('Nº de Instâncias (percentual)')
ax.set_ylabel('Acurácia')
fig.savefig('figure5.png')   # save the figure to file
fig.show()
# Out:
# C:\Users\55989\AppData\Local\Temp/ipykernel_7284/2458416178.py:7: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
